# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanjateacherson/SMHRD/blob/main/python/03_01pandas_exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# 1. exam 데이터 불러오기
exam = pd.read_csv('/content/drive/MyDrive/data/exam.csv')
exam
# Out:
#      id  nclass  math  english  science
# 0     1       1    52       98       50
# 1     2       1    60       97       58
# 2     3       1    44       86       78
# 3     4       1    35       98       58
# 4     5       1    27       80       65
# ..  ...     ...   ...      ...      ...
# 95   96       5    58       98       65
# 96   97       5    65       68       98
# 97   98       5    80       78       90
# 98   99       5    89       68       87
# 99  100       5    78       83       58
#
# [100 rows x 5 columns]

# %%
# 2. exam 데이터의 정보 확인해보기
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       100 non-null    int64
#  1   nclass   100 non-null    int64
#  2   math     100 non-null    int64
#  3   english  100 non-null    int64
#  4   science  100 non-null    int64
# dtypes: int64(5)
# memory usage: 4.0 KB

# %%
# 3. exam 데이터의 요약보기

# %%
# 4.exam 데이터의 각 평균값 구하기
exam['math']
exam['english']
exam['science']
# Out:
# 0     50
# 1     58
# 2     78
# 3     58
# 4     65
#       ..
# 95    65
# 96    98
# 97    90
# 98    87
# 99    58
# Name: science, Length: 100, dtype: int64

# %%
exam_mean = (exam['math']+ exam['english']+exam['sience'])

# %%
# 5. 평균 컬럼 파생변수 만들기
exam['avg'] = exam_mean
exam
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-be4c4690681d> in <cell line: 2>()
#       1 # 5. 평균 컬럼 파생변수 만들기
# ----> 2 exam['avg'] = exam_mean
#       3 exam
#
# NameError: name 'exam_mean' is not defined
